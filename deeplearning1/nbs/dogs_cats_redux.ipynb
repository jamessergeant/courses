# %% [markdown]
# # Dogs vs Cat Redux

# %% [markdown]
# In this tutorial, you will learn how generate and submit predictions to a Kaggle competiton
#
# [Dogs vs. Cats Redux: Kernels Edition](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition)

# %% [markdown]
# To start you will need to download and unzip the competition data from Kaggle and ensure your directory structure looks like this
# ```
# utils/
#     vgg16.py
#     utils.py
# lesson1/
#     redux.ipynb
#     data/
#         redux/
#             train/
#                 cat.437.jpg
#                 dog.9924.jpg
#                 cat.1029.jpg
#                 dog.4374.jpg
#             test/
#                 231.jpg
#                 325.jpg
#                 1235.jpg
#                 9923.jpg
# ```
#
# You can download the data files from the competition page [here](https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/data) or you can download them from the command line using the [Kaggle CLI](https://github.com/floydwch/kaggle-cli).
#
# You should launch your notebook inside the lesson1 directory
# ```
# cd lesson1
# jupyter notebook
# ```

# %%
#Verify we are in the lesson1 directory
# %pwd
# Out:
# '/home/james/co/courses/deeplearning1/nbs'

# %%
#Create references to important directories we will use over and over
import os, sys
current_dir = os.getcwd()
LESSON_HOME_DIR = current_dir
# %cd $LESSON_HOME_DIR
DATA_HOME_DIR = current_dir+'/data/redux'
# Out:
# /home/james/co/courses/deeplearning1/nbs

# %%
#Allow relative imports to directories above lesson1/
sys.path.insert(1, os.path.join(sys.path[0], '..'))

#import modules
from utils import *
from vgg16 import Vgg16

#Instantiate plotting tool
#In Jupyter notebooks, you will need to run this command before doing any plotting
# %matplotlib inline
# Out:
# Using cuDNN version 5105 on context None
# Mapped name None to device cuda0: GeForce GTX 1070 (0000:01:00.0)
# Using Theano backend.

# %% [markdown]
# ## Action Plan
# 1. Create Validation and Sample sets
# 2. Rearrange image files into their respective directories
# 3. Finetune and Train model
# 4. Generate predictions
# 5. Validate predictions
# 6. Submit predictions to Kaggle

# %% [markdown]
# ## Create validation set and sample

# %%
#Create directories
print(DATA_HOME_DIR)
# %mkdir $DATA_HOME_DIR
# %cd $DATA_HOME_DIR
# %kg config -g -u 'james_sergeant@hotmail.com' -p '#########' -c 'dogs-vs-cats-redux-kernels-edition'
# !kg download
# !unzip test.zip
# !unzip train.zip
# %mkdir valid
# %mkdir results
# %mkdir -p sample/train
# %mkdir -p sample/test
# %mkdir -p sample/valid
# %mkdir -p sample/results
# %mkdir -p test/unknown
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux
# mkdir: cannot create directory ‘/home/james/co/courses/deeplearning1/nbs/data/redux’: File exists
# /home/james/co/courses/deeplearning1/nbs/data/redux
# Archive:  test.zip
#   inflating: test/1.jpg
#   inflating: test/10.jpg
#   inflating: test/100.jpg
#   inflating: test/1000.jpg
#   inflating: test/10000.jpg
#   inflating: test/10001.jpg
#   inflating: test/10002.jpg
#   inflating: test/10003.jpg
#   inflating: test/10004.jpg
#   inflating: test/10005.jpg
#   inflating: test/10006.jpg
#   inflating: test/10007.jpg
#   inflating: test/10008.jpg
#   inflating: test/10009.jpg
#   inflating: test/1001.jpg
#   inflating: test/10010.jpg
#   inflating: test/10011.jpg
#   inflating: test/10012.jpg
#   inflating: test/10013.jpg
#   inflating: test/10014.jpg
#   inflating: test/10015.jpg
#   inflating: test/10016.jpg
#   inflating: test/10017.jpg
#   inflating: test/10018.jpg
#   inflating: test/10019.jpg
#   inflating: test/1002.jpg
#   inflating: test/10020.jpg
#   inflating: test/10021.jpg
#   inflating: test/10022.jpg
#   inflating: test/10023.jpg
#   inflating: test/10024.jpg
#   inflating: test/10025.jpg
#   inflating: test/10026.jpg
#   inflating: test/10027.jpg
#   inflating: test/10028.jpg
#   inflating: test/10029.jpg
#   inflating: test/1003.jpg
#   inflating: test/10030.jpg
#   inflating: test/10031.jpg
#   inflating: test/10032.jpg
#   inflating: test/10033.jpg
#   inflating: test/10034.jpg
#   inflating: test/10035.jpg
#   inflating: test/10036.jpg
#   inflating: test/10037.jpg
#   inflating: test/10038.jpg
#   inflating: test/10039.jpg
#   inflating: test/1004.jpg
#   inflating: test/10040.jpg
#   inflating: test/10041.jpg
#   inflating: test/10042.jpg
#   inflating: test/10043.jpg
#   inflating: test/10044.jpg
#   inflating: test/10045.jpg
#   inflating: test/10046.jpg
#   inflating: test/10047.jpg
#   inflating: test/10048.jpg
#   inflating: test/10049.jpg
#   inflating: test/1005.jpg
#   inflating: test/10050.jpg
#   inflating: test/10051.jpg
#   inflating: test/10052.jpg
#   inflating: test/10053.jpg
#   inflating: test/10054.jpg
#   inflating: test/10055.jpg
#   inflating: test/10056.jpg
#   inflating: test/10057.jpg
#   inflating: test/10058.jpg
#   inflating: test/10059.jpg
#   inflating: test/1006.jpg
#   inflating: test/10060.jpg
#   inflating: test/10061.jpg
#   inflating: test/10062.jpg
#   inflating: test/10063.jpg
#   inflating: test/10064.jpg
#   inflating: test/10065.jpg
#   inflating: test/10066.jpg
#   inflating: test/10067.jpg
#   inflating: test/10068.jpg
#   inflating: test/10069.jpg
#   inflating: test/1007.jpg
#   inflating: test/10070.jpg
#   inflating: test/10071.jpg
#   inflating: test/10072.jpg
#   inflating: test/10073.jpg
#   inflating: test/10074.jpg
#   inflating: test/10075.jpg
#   inflating: test/10076.jpg
#   inflating: test/10077.jpg
#   inflating: test/10078.jpg
#   inflating: test/10079.jpg
#   inflating: test/1008.jpg
#   inflating: test/10080.jpg
#   inflating: test/10081.jpg
#   inflating: test/10082.jpg
#   inflating: test/10083.jpg
#   inflating: test/10084.jpg
#   inflating: test/10085.jpg
#   inflating: test/10086.jpg
#   inflating: test/10087.jpg
#   inflating: test/10088.jpg
#   inflating: test/10089.jpg
#   inflating: test/1009.jpg
#   inflating: test/10090.jpg
#   inflating: test/10091.jpg
#   inflating: test/10092.jpg
#   inflating: test/10093.jpg
#   inflating: test/10094.jpg
#   inflating: test/10095.jpg
#   inflating: test/10096.jpg
#   inflating: test/10097.jpg
#   inflating: test/10098.jpg
#   inflating: test/10099.jpg
#   inflating: test/101.jpg
#   inflating: test/1010.jpg
#   inflating: test/10100.jpg
#   inflating: test/10101.jpg
#   inflating: test/10102.jpg
#   inflating: test/10103.jpg
#   inflating: test/10104.jpg
#   inflating: test/10105.jpg
#   inflating: test/10106.jpg
#   inflating: test/10107.jpg
#   inflating: test/10108.jpg
#   inflating: test/10109.jpg
#   inflating: test/1011.jpg
#   inflating: test/10110.jpg
#   inflating: test/10111.jpg
#   inflating: test/10112.jpg
#   inflating: test/10113.jpg
#   inflating: test/10114.jpg
#   inflating: test/10115.jpg
#   inflating: test/10116.jpg
#   inflating: test/10117.jpg
#   inflating: test/10118.jpg
#   inflating: test/10119.jpg
#   inflating: test/1012.jpg
#   inflating: test/10120.jpg
#   inflating: test/10121.jpg
#   inflating: test/10122.jpg
#   inflating: test/10123.jpg
#   inflating: test/10124.jpg
#   inflating: test/10125.jpg
#   inflating: test/10126.jpg
#   inflating: test/10127.jpg
#   inflating: test/10128.jpg
#   inflating: test/10129.jpg
#   inflating: test/1013.jpg
#   inflating: test/10130.jpg
#   inflating: test/10131.jpg
#   inflating: test/10132.jpg
#   inflating: test/10133.jpg
#   inflating: test/10134.jpg
#   inflating: test/10135.jpg
#   inflating: test/10136.jpg
#   inflating: test/10137.jpg
#   inflating: test/10138.jpg
#   inflating: test/10139.jpg
#   inflating: test/1014.jpg
#   inflating: test/10140.jpg
#   inflating: test/10141.jpg
#   inflating: test/10142.jpg
#   inflating: test/10143.jpg
#   inflating: test/10144.jpg
#   inflating: test/10145.jpg
#   inflating: test/10146.jpg
#   inflating: test/10147.jpg
#   inflating: test/10148.jpg
#   inflating: test/10149.jpg
#   inflating: test/1015.jpg
#   inflating: test/10150.jpg
#   inflating: test/10151.jpg
#   inflating: test/10152.jpg
#   inflating: test/10153.jpg
#   inflating: test/10154.jpg
#   inflating: test/10155.jpg
#   inflating: test/10156.jpg
#   inflating: test/10157.jpg
#   inflating: test/10158.jpg
#   inflating: test/10159.jpg
#   inflating: test/1016.jpg
#   inflating: test/10160.jpg
#   inflating: test/10161.jpg
#   inflating: test/10162.jpg
#   inflating: test/10163.jpg
#   inflating: test/10164.jpg
#   inflating: test/10165.jpg
#   inflating: test/10166.jpg
#   inflating: test/10167.jpg
#   inflating: test/10168.jpg
#   inflating: test/10169.jpg
#   inflating: test/1017.jpg
#   inflating: test/10170.jpg
#   inflating: test/10171.jpg
#   inflating: test/10172.jpg
#   inflating: test/10173.jpg
#   inflating: test/10174.jpg
#   inflating: test/10175.jpg
#   inflating: test/10176.jpg
#   inflating: test/10177.jpg
#   inflating: test/10178.jpg
#   inflating: test/10179.jpg
#   inflating: test/1018.jpg
#   inflating: test/10180.jpg
#   inflating: test/10181.jpg
#   inflating: test/10182.jpg
#   inflating: test/10183.jpg
#   inflating: test/10184.jpg
#   inflating: test/10185.jpg
#   inflating: test/10186.jpg
#   inflating: test/10187.jpg
#   inflating: test/10188.jpg
#   inflating: test/10189.jpg
#   inflating: test/1019.jpg
#   inflating: test/10190.jpg
#   inflating: test/10191.jpg
#   inflating: test/10192.jpg
#   inflating: test/10193.jpg
#   inflating: test/10194.jpg
#   inflating: test/10195.jpg
#   inflating: test/10196.jpg
#   inflating: test/10197.jpg
#   inflating: test/10198.jpg
#   inflating: test/10199.jpg
#   inflating: test/102.jpg
#   inflating: test/1020.jpg
#   inflating: test/10200.jpg
#   inflating: test/10201.jpg
#   inflating: test/10202.jpg
#   inflating: test/10203.jpg
#   inflating: test/10204.jpg
#   inflating: test/10205.jpg
#   inflating: test/10206.jpg
#   inflating: test/10207.jpg
#   inflating: test/10208.jpg
#   inflating: test/10209.jpg
#   inflating: test/1021.jpg
#   inflating: test/10210.jpg
#   inflating: test/10211.jpg
#   inflating: test/10212.jpg
#   inflating: test/10213.jpg
#   inflating: test/10214.jpg
#   inflating: test/10215.jpg
#   inflating: test/10216.jpg
#   inflating: test/10217.jpg
#   inflating: test/10218.jpg
#   inflating: test/10219.jpg
#   inflating: test/1022.jpg
#   inflating: test/10220.jpg
#   inflating: test/10221.jpg
#   inflating: test/10222.jpg
#   inflating: test/10223.jpg
#   inflating: test/10224.jpg
#   inflating: test/10225.jpg
#   inflating: test/10226.jpg
#   inflating: test/10227.jpg
#   inflating: test/10228.jpg
#   inflating: test/10229.jpg
#   inflating: test/1023.jpg
#   inflating: test/10230.jpg
#   inflating: test/10231.jpg
#   inflating: test/10232.jpg
#   inflating: test/10233.jpg
#   inflating: test/10234.jpg
#   inflating: test/10235.jpg
#   inflating: test/10236.jpg
#   inflating: test/10237.jpg
#   inflating: test/10238.jpg
#   inflating: test/10239.jpg
#   inflating: test/1024.jpg
#   inflating: test/10240.jpg
#   inflating: test/10241.jpg
#   inflating: test/10242.jpg
#   inflating: test/10243.jpg
#   inflating: test/10244.jpg
#   inflating: test/10245.jpg
#   inflating: test/10246.jpg
#   inflating: test/10247.jpg
#   inflating: test/10248.jpg
#   inflating: test/10249.jpg
#   inflating: test/1025.jpg
#   inflating: test/10250.jpg
#   inflating: test/10251.jpg
#   inflating: test/10252.jpg
#   inflating: test/10253.jpg
#   inflating: test/10254.jpg
#   inflating: test/10255.jpg
#   inflating: test/10256.jpg
#   inflating: test/10257.jpg
#   inflating: test/10258.jpg
#   inflating: test/10259.jpg
#   inflating: test/1026.jpg
#   inflating: test/10260.jpg
#   inflating: test/10261.jpg
#   inflating: test/10262.jpg
#   inflating: test/10263.jpg
#   inflating: test/10264.jpg
#   inflating: test/10265.jpg
#   inflating: test/10266.jpg
#   inflating: test/10267.jpg
#   inflating: test/10268.jpg
#   inflating: test/10269.jpg
#   inflating: test/1027.jpg
#   inflating: test/10270.jpg
#   inflating: test/10271.jpg
#   inflating: test/10272.jpg
#   inflating: test/10273.jpg
#   inflating: test/10274.jpg
#   inflating: test/10275.jpg
#   inflating: test/10276.jpg
#   inflating: test/10277.jpg
#   inflating: test/10278.jpg
#   inflating: test/10279.jpg
#   inflating: test/1028.jpg
#   inflating: test/10280.jpg
#   inflating: test/10281.jpg
#   inflating: test/10282.jpg
#   inflating: test/10283.jpg
#   inflating: test/10284.jpg
#   inflating: test/10285.jpg
#   inflating: test/10286.jpg
#   inflating: test/10287.jpg
#   inflating: test/10288.jpg
#   inflating: test/10289.jpg
#   inflating: test/1029.jpg
#   inflating: test/10290.jpg
#   inflating: test/10291.jpg
#   inflating: test/10292.jpg
#   inflating: test/10293.jpg
#   inflating: test/10294.jpg
#   inflating: test/10295.jpg
#   inflating: test/10296.jpg
#   inflating: test/10297.jpg
#   inflating: test/10298.jpg
#   inflating: test/10299.jpg
#   inflating: test/103.jpg
#   inflating: test/1030.jpg
#   inflating: test/10300.jpg
#   inflating: test/10301.jpg
#   inflating: test/10302.jpg
#   inflating: test/10303.jpg
#   inflating: test/10304.jpg
#   inflating: test/10305.jpg
#   inflating: test/10306.jpg
#   inflating: test/10307.jpg
#   inflating: test/10308.jpg
#   inflating: test/10309.jpg
#   inflating: test/1031.jpg
#   inflating: test/10310.jpg
#   inflating: test/10311.jpg
#   inflating: test/10312.jpg
#   inflating: test/10313.jpg
#   inflating: test/10314.jpg
#   inflating: test/10315.jpg
#   inflating: test/10316.jpg
#   inflating: test/10317.jpg
#   inflating: test/10318.jpg
#   inflating: test/10319.jpg
#   inflating: test/1032.jpg
#   inflating: test/10320.jpg
#   inflating: test/10321.jpg
#   inflating: test/10322.jpg
#   inflating: test/10323.jpg
#   inflating: test/10324.jpg
#   inflating: test/10325.jpg
#   inflating: test/10326.jpg
#   inflating: test/10327.jpg
#   inflating: test/10328.jpg
#   inflating: test/10329.jpg
#   inflating: test/1033.jpg
#   inflating: test/10330.jpg
#   inflating: test/10331.jpg
#   inflating: test/10332.jpg
#   inflating: test/10333.jpg
#   inflating: test/10334.jpg
#   inflating: test/10335.jpg
#   inflating: test/10336.jpg
#   inflating: test/10337.jpg
#   inflating: test/10338.jpg
#   inflating: test/10339.jpg
#   inflating: test/1034.jpg
#   inflating: test/10340.jpg
#   inflating: test/10341.jpg
#   inflating: test/10342.jpg
#   inflating: test/10343.jpg
#   inflating: test/10344.jpg
#   inflating: test/10345.jpg
#   inflating: test/10346.jpg
#   inflating: test/10347.jpg
#   inflating: test/10348.jpg
#   inflating: test/10349.jpg
#   inflating: test/1035.jpg
#   inflating: test/10350.jpg
#   inflating: test/10351.jpg
#   inflating: test/10352.jpg
#   inflating: test/10353.jpg
#   inflating: test/10354.jpg
#   inflating: test/10355.jpg
#   inflating: test/10356.jpg
#   inflating: test/10357.jpg
#   inflating: test/10358.jpg
#   inflating: test/10359.jpg
#   inflating: test/1036.jpg
#   inflating: test/10360.jpg
#   inflating: test/10361.jpg
#   inflating: test/10362.jpg
#   inflating: test/10363.jpg
#   inflating: test/10364.jpg
#   inflating: test/10365.jpg
#   inflating: test/10366.jpg
#   inflating: test/10367.jpg
#   inflating: test/10368.jpg
#   inflating: test/10369.jpg
#   inflating: test/1037.jpg
#   inflating: test/10370.jpg
#   inflating: test/10371.jpg
#   inflating: test/10372.jpg
#   inflating: test/10373.jpg
#   inflating: test/10374.jpg
#   inflating: test/10375.jpg
#   inflating: test/10376.jpg
#   inflating: test/10377.jpg
#   inflating: test/10378.jpg
#   inflating: test/10379.jpg
#   inflating: test/1038.jpg
#   inflating: test/10380.jpg
#   inflating: test/10381.jpg
#   inflating: test/10382.jpg
#   inflating: test/10383.jpg
#   inflating: test/10384.jpg
#   inflating: test/10385.jpg
#   inflating: test/10386.jpg
#   inflating: test/10387.jpg
#   inflating: test/10388.jpg
#   inflating: test/10389.jpg
#   inflating: test/1039.jpg
#   inflating: test/10390.jpg
#   inflating: test/10391.jpg
#   inflating: test/10392.jpg
#   inflating: test/10393.jpg
#   inflating: test/10394.jpg
#   inflating: test/10395.jpg
#   inflating: test/10396.jpg
#   inflating: test/10397.jpg
#   inflating: test/10398.jpg
#   inflating: test/10399.jpg
#   inflating: test/104.jpg
#   inflating: test/1040.jpg
#   inflating: test/10400.jpg
#   inflating: test/10401.jpg
#   inflating: test/10402.jpg
#   inflating: test/10403.jpg
#   inflating: test/10404.jpg
#   inflating: test/10405.jpg
#   inflating: test/10406.jpg
#   inflating: test/10407.jpg
#   inflating: test/10408.jpg
#   inflating: test/10409.jpg
#   inflating: test/1041.jpg
#   inflating: test/10410.jpg
#   inflating: test/10411.jpg
#   inflating: test/10412.jpg
#   inflating: test/10413.jpg
#   inflating: test/10414.jpg
#   inflating: test/10415.jpg
#   inflating: test/10416.jpg
#   inflating: test/10417.jpg
#   inflating: test/10418.jpg
#   inflating: test/10419.jpg
#   inflating: test/1042.jpg
#   inflating: test/10420.jpg
#   inflating: test/10421.jpg
#   inflating: test/10422.jpg
#   inflating: test/10423.jpg
#   inflating: test/10424.jpg
#   inflating: test/10425.jpg
#   inflating: test/10426.jpg
#   inflating: test/10427.jpg
#   inflating: test/10428.jpg
#   inflating: test/10429.jpg
#   inflating: test/1043.jpg
#   inflating: test/10430.jpg
#   inflating: test/10431.jpg
#   inflating: test/10432.jpg
#   inflating: test/10433.jpg
#   inflating: test/10434.jpg
#   inflating: test/10435.jpg
#   inflating: test/10436.jpg
#   inflating: test/10437.jpg
#   inflating: test/10438.jpg
#   inflating: test/10439.jpg
#   inflating: test/1044.jpg
#   inflating: test/10440.jpg
#   inflating: test/10441.jpg
#   inflating: test/10442.jpg
#   inflating: test/10443.jpg
#   inflating: test/10444.jpg
#   inflating: test/10445.jpg
#   inflating: test/10446.jpg
#   inflating: test/10447.jpg
#   inflating: test/10448.jpg
#   inflating: test/10449.jpg
#   inflating: test/1045.jpg
#   inflating: test/10450.jpg
#   inflating: test/10451.jpg
#   inflating: test/10452.jpg
#   inflating: test/10453.jpg
#   inflating: test/10454.jpg
#   inflating: test/10455.jpg
#   inflating: test/10456.jpg
#   inflating: test/10457.jpg
#   inflating: test/10458.jpg
#   inflating: test/10459.jpg
#   inflating: test/1046.jpg
#   inflating: test/10460.jpg
#   inflating: test/10461.jpg
#   inflating: test/10462.jpg
#   inflating: test/10463.jpg
#   inflating: test/10464.jpg
#   inflating: test/10465.jpg
#   inflating: test/10466.jpg
#   inflating: test/10467.jpg
#   inflating: test/10468.jpg
#   inflating: test/10469.jpg
#   inflating: test/1047.jpg
#   inflating: test/10470.jpg
#   inflating: test/10471.jpg
#   inflating: test/10472.jpg
#   inflating: test/10473.jpg
#   inflating: test/10474.jpg
#   inflating: test/10475.jpg
#   inflating: test/10476.jpg
#   inflating: test/10477.jpg
#   inflating: test/10478.jpg
#   inflating: test/10479.jpg
#   inflating: test/1048.jpg
#   inflating: test/10480.jpg
#   inflating: test/10481.jpg
#   inflating: test/10482.jpg
#   inflating: test/10483.jpg
#   inflating: test/10484.jpg
#   inflating: test/10485.jpg
#   inflating: test/10486.jpg
#   inflating: test/10487.jpg
#   inflating: test/10488.jpg
#   inflating: test/10489.jpg
#   inflating: test/1049.jpg
#   inflating: test/10490.jpg
#   inflating: test/10491.jpg
#   inflating: test/10492.jpg
#   inflating: test/10493.jpg
#   inflating: test/10494.jpg
#   inflating: test/10495.jpg
#   inflating: test/10496.jpg
#   inflating: test/10497.jpg
#   inflating: test/10498.jpg
#   inflating: test/10499.jpg
#   inflating: test/105.jpg
#   inflating: test/1050.jpg
#   inflating: test/10500.jpg
#   inflating: test/10501.jpg
#   inflating: test/10502.jpg
#   inflating: test/10503.jpg
#   inflating: test/10504.jpg
#   inflating: test/10505.jpg
#   inflating: test/10506.jpg
#   inflating: test/10507.jpg
#   inflating: test/10508.jpg
#   inflating: test/10509.jpg
#   inflating: test/1051.jpg
#   inflating: test/10510.jpg
#   inflating: test/10511.jpg
#   inflating: test/10512.jpg
#   inflating: test/10513.jpg
#   inflating: test/10514.jpg
#   inflating: test/10515.jpg
#   inflating: test/10516.jpg
#   inflating: test/10517.jpg
#   inflating: test/10518.jpg
#   inflating: test/10519.jpg
#   inflating: test/1052.jpg
#   inflating: test/10520.jpg
#   inflating: test/10521.jpg
#   inflating: test/10522.jpg
#   inflating: test/10523.jpg
#   inflating: test/10524.jpg
#   inflating: test/10525.jpg
#   inflating: test/10526.jpg
#   inflating: test/10527.jpg
#   inflating: test/10528.jpg
#   inflating: test/10529.jpg
#   inflating: test/1053.jpg
#   inflating: test/10530.jpg
#   inflating: test/10531.jpg
#   inflating: test/10532.jpg
#   inflating: test/10533.jpg
#   inflating: test/10534.jpg
#   inflating: test/10535.jpg
#   inflating: test/10536.jpg
#   inflating: test/10537.jpg
#   inflating: test/10538.jpg
#   inflating: test/10539.jpg
#   inflating: test/1054.jpg
#   inflating: test/10540.jpg
#   inflating: test/10541.jpg
#   inflating: test/10542.jpg
#   inflating: test/10543.jpg
#   inflating: test/10544.jpg
#   inflating: test/10545.jpg
#   inflating: test/10546.jpg
#   inflating: test/10547.jpg
#   inflating: test/10548.jpg
#   inflating: test/10549.jpg
#   inflating: test/1055.jpg
#   inflating: test/10550.jpg
#   inflating: test/10551.jpg
#   inflating: test/10552.jpg
#   inflating: test/10553.jpg
#   inflating: test/10554.jpg
#   inflating: test/10555.jpg
#   inflating: test/10556.jpg
#   inflating: test/10557.jpg
#   inflating: test/10558.jpg
#   inflating: test/10559.jpg
#   inflating: test/1056.jpg
#   inflating: test/10560.jpg
#   inflating: test/10561.jpg
#   inflating: test/10562.jpg
#   inflating: test/10563.jpg
#   inflating: test/10564.jpg
#   inflating: test/10565.jpg
#   inflating: test/10566.jpg
#   inflating: test/10567.jpg
#   inflating: test/10568.jpg
#   inflating: test/10569.jpg
#   inflating: test/1057.jpg
#   inflating: test/10570.jpg
#   inflating: test/10571.jpg
#   inflating: test/10572.jpg
#   inflating: test/10573.jpg
#   inflating: test/10574.jpg
#   inflating: test/10575.jpg
#   inflating: test/10576.jpg
#   inflating: test/10577.jpg
#   inflating: test/10578.jpg
#   inflating: test/10579.jpg
#   inflating: test/1058.jpg
#   inflating: test/10580.jpg
#   inflating: test/10581.jpg
#   inflating: test/10582.jpg
#   inflating: test/10583.jpg
#   inflating: test/10584.jpg
#   inflating: test/10585.jpg
#   inflating: test/10586.jpg
#   inflating: test/10587.jpg
#   inflating: test/10588.jpg
#   inflating: test/10589.jpg
#   inflating: test/1059.jpg
#   inflating: test/10590.jpg
#   inflating: test/10591.jpg
#   inflating: test/10592.jpg
#   inflating: test/10593.jpg
#   inflating: test/10594.jpg
#   inflating: test/10595.jpg
#   inflating: test/10596.jpg
#   inflating: test/10597.jpg
#   inflating: test/10598.jpg
#   inflating: test/10599.jpg
#   inflating: test/106.jpg
#   inflating: test/1060.jpg
#   inflating: test/10600.jpg
#   inflating: test/10601.jpg
#   inflating: test/10602.jpg
#   inflating: test/10603.jpg
#   inflating: test/10604.jpg
#   inflating: test/10605.jpg
#   inflating: test/10606.jpg
#   inflating: test/10607.jpg
#   inflating: test/10608.jpg
#   inflating: test/10609.jpg
#   inflating: test/1061.jpg
#   inflating: test/10610.jpg
#   inflating: test/10611.jpg
#   inflating: test/10612.jpg
#   inflating: test/10613.jpg
#   inflating: test/10614.jpg
#   inflating: test/10615.jpg
#   inflating: test/10616.jpg
#   inflating: test/10617.jpg
#   inflating: test/10618.jpg
#   inflating: test/10619.jpg
#   inflating: test/1062.jpg
#   inflating: test/10620.jpg
#   inflating: test/10621.jpg
#   inflating: test/10622.jpg
#   inflating: test/10623.jpg
#   inflating: test/10624.jpg
#   inflating: test/10625.jpg
#   inflating: test/10626.jpg
#   inflating: test/10627.jpg
#   inflating: test/10628.jpg
#   inflating: test/10629.jpg
#   inflating: test/1063.jpg
#   inflating: test/10630.jpg
#   inflating: test/10631.jpg
#   inflating: test/10632.jpg
#   inflating: test/10633.jpg
#   inflating: test/10634.jpg
#   inflating: test/10635.jpg
#   inflating: test/10636.jpg
#   inflating: test/10637.jpg
#   inflating: test/10638.jpg
#   inflating: test/10639.jpg
#   inflating: test/1064.jpg
#   inflating: test/10640.jpg
#   inflating: test/10641.jpg
#   inflating: test/10642.jpg
#   inflating: test/10643.jpg
#   inflating: test/10644.jpg
#   inflating: test/10645.jpg
#   inflating: test/10646.jpg
#   inflating: test/10647.jpg
#   inflating: test/10648.jpg
#   inflating: test/10649.jpg
#   inflating: test/1065.jpg
#   inflating: test/10650.jpg
#   inflating: test/10651.jpg
#   inflating: test/10652.jpg
#   inflating: test/10653.jpg
#   inflating: test/10654.jpg
#   inflating: test/10655.jpg
#   inflating: test/10656.jpg
#   inflating: test/10657.jpg
#   inflating: test/10658.jpg
#   inflating: test/10659.jpg
#   inflating: test/1066.jpg
#   inflating: test/10660.jpg
#   inflating: test/10661.jpg
#   inflating: test/10662.jpg
#   inflating: test/10663.jpg
#   inflating: test/10664.jpg
#   inflating: test/10665.jpg
#   inflating: test/10666.jpg
#   inflating: test/10667.jpg
#   inflating: test/10668.jpg
#   inflating: test/10669.jpg
#   inflating: test/1067.jpg
#   inflating: test/10670.jpg
#   inflating: test/10671.jpg
#   inflating: test/10672.jpg
#   inflating: test/10673.jpg
#   inflating: test/10674.jpg
#   inflating: test/10675.jpg
#   inflating: test/10676.jpg
#   inflating: test/10677.jpg
#   inflating: test/10678.jpg
#   inflating: test/10679.jpg
#   inflating: test/1068.jpg
#   inflating: test/10680.jpg
#   inflating: test/10681.jpg
#   inflating: test/10682.jpg
#   inflating: test/10683.jpg
#   inflating: test/10684.jpg
#   inflating: test/10685.jpg
#   inflating: test/10686.jpg
#   inflating: test/10687.jpg
#   inflating: test/10688.jpg
#   inflating: test/10689.jpg
#   inflating: test/1069.jpg
#   inflating: test/10690.jpg
#   inflating: test/10691.jpg
#   inflating: test/10692.jpg
#   inflating: test/10693.jpg
#   inflating: test/10694.jpg
#   inflating: test/10695.jpg
#   inflating: test/10696.jpg
#   inflating: test/10697.jpg
#   inflating: test/10698.jpg
#   inflating: test/10699.jpg
#   inflating: test/107.jpg
#   inflating: test/1070.jpg
#   inflating: test/10700.jpg
#   inflating: test/10701.jpg
#   inflating: test/10702.jpg
#   inflating: test/10703.jpg
#   inflating: test/10704.jpg
#   inflating: test/10705.jpg
#   inflating: test/10706.jpg
#   inflating: test/10707.jpg
#   inflating: test/10708.jpg
#   inflating: test/10709.jpg
#   inflating: test/1071.jpg
#   inflating: test/10710.jpg
#   inflating: test/10711.jpg
#   inflating: test/10712.jpg
#   inflating: test/10713.jpg
#   inflating: test/10714.jpg
#   inflating: test/10715.jpg
#   inflating: test/10716.jpg
#   inflating: test/10717.jpg
#   inflating: test/10718.jpg
#   inflating: test/10719.jpg
#   inflating: test/1072.jpg
#   inflating: test/10720.jpg
#   inflating: test/10721.jpg
#   inflating: test/10722.jpg
#   inflating: test/10723.jpg
#   inflating: test/10724.jpg
#   inflating: test/10725.jpg
#   inflating: test/10726.jpg
#   inflating: test/10727.jpg
#   inflating: test/10728.jpg
#   inflating: test/10729.jpg
#   inflating: test/1073.jpg
#   inflating: test/10730.jpg
#   inflating: test/10731.jpg
#   inflating: test/10732.jpg
#   inflating: test/10733.jpg
#   inflating: test/10734.jpg
#   inflating: test/10735.jpg
#   inflating: test/10736.jpg
#   inflating: test/10737.jpg
#   inflating: test/10738.jpg
#   inflating: test/10739.jpg
#   inflating: test/1074.jpg
#   inflating: test/10740.jpg
#   inflating: test/10741.jpg
#   inflating: test/10742.jpg
#   inflating: test/10743.jpg
#   inflating: test/10744.jpg
#   inflating: test/10745.jpg
#   inflating: test/10746.jpg
#   inflating: test/10747.jpg
#   inflating: test/10748.jpg
#   inflating: test/10749.jpg
#   inflating: test/1075.jpg
#   inflating: test/10750.jpg
#   inflating: test/10751.jpg
#   inflating: test/10752.jpg
#   inflating: test/10753.jpg
#   inflating: test/10754.jpg
#   inflating: test/10755.jpg
#   inflating: test/10756.jpg
#   inflating: test/10757.jpg
#   inflating: test/10758.jpg
#   inflating: test/10759.jpg
#   inflating: test/1076.jpg
#   inflating: test/10760.jpg
#   inflating: test/10761.jpg
#   inflating: test/10762.jpg
#   inflating: test/10763.jpg
#   inflating: test/10764.jpg
#   inflating: test/10765.jpg
#   inflating: test/10766.jpg
#   inflating: test/10767.jpg
#   inflating: test/10768.jpg
#   inflating: test/10769.jpg
#   inflating: test/1077.jpg
#   inflating: test/10770.jpg
#   inflating: test/10771.jpg
#   inflating: test/10772.jpg
#   inflating: test/10773.jpg
#   inflating: test/10774.jpg
#   inflating: test/10775.jpg
#   inflating: test/10776.jpg
#   inflating: test/10777.jpg
#   inflating: test/10778.jpg
#   inflating: test/10779.jpg
#   inflating: test/1078.jpg
#   inflating: test/10780.jpg
#   inflating: test/10781.jpg
#   inflating: test/10782.jpg
#   inflating: test/10783.jpg
#   inflating: test/10784.jpg
#   inflating: test/10785.jpg
#   inflating: test/10786.jpg
#   inflating: test/10787.jpg
#   inflating: test/10788.jpg
#   inflating: test/10789.jpg
#   inflating: test/1079.jpg
#   inflating: test/10790.jpg
#   inflating: test/10791.jpg
#   inflating: test/10792.jpg
#   inflating: test/10793.jpg
#   inflating: test/10794.jpg
#   inflating: test/10795.jpg
#   inflating: test/10796.jpg
#   inflating: test/10797.jpg
#   inflating: test/10798.jpg
#   inflating: test/10799.jpg
#   inflating: test/108.jpg
#   inflating: test/1080.jpg
#   inflating: test/10800.jpg
#   inflating: test/10801.jpg
#   inflating: test/10802.jpg
#   inflating: test/10803.jpg
#   inflating: test/10804.jpg
#   inflating: test/10805.jpg
#   inflating: test/10806.jpg
#   inflating: test/10807.jpg
#   inflating: test/10808.jpg
#   inflating: test/10809.jpg
#   inflating: test/1081.jpg
#   inflating: test/10810.jpg
#   inflating: test/10811.jpg
#   inflating: test/10812.jpg
#   inflating: test/10813.jpg
#   inflating: test/10814.jpg
#   inflating: test/10815.jpg
#   inflating: test/10816.jpg
#   inflating: test/10817.jpg
#   inflating: test/10818.jpg
#   inflating: test/10819.jpg
#   inflating: test/1082.jpg
#   inflating: test/10820.jpg
#   inflating: test/10821.jpg
#   inflating: test/10822.jpg
#   inflating: test/10823.jpg
#   inflating: test/10824.jpg
#   inflating: test/10825.jpg
#   inflating: test/10826.jpg
#   inflating: test/10827.jpg
#   inflating: test/10828.jpg
#   inflating: test/10829.jpg
#   inflating: test/1083.jpg
#   inflating: test/10830.jpg
#   inflating: test/10831.jpg
#   inflating: test/10832.jpg
#   inflating: test/10833.jpg
#   inflating: test/10834.jpg
#   inflating: test/10835.jpg
#   inflating: test/10836.jpg
#   inflating: test/10837.jpg
#   inflating: test/10838.jpg
#   inflating: test/10839.jpg
#   inflating: test/1084.jpg
#   inflating: test/10840.jpg
#   inflating: test/10841.jpg
#   inflating: test/10842.jpg
#   inflating: test/10843.jpg
#   inflating: test/10844.jpg
#   inflating: test/10845.jpg
#   inflating: test/10846.jpg
#   inflating: test/10847.jpg
#   inflating: test/10848.jpg
#   inflating: test/10849.jpg
#   inflating: test/1085.jpg
#   inflating: test/10850.jpg
#   inflating: test/10851.jpg
#   inflating: test/10852.jpg
#   inflating: test/10853.jpg
#   inflating: test/10854.jpg
#   inflating: test/10855.jpg
#   inflating: test/10856.jpg
#   inflating: test/10857.jpg
#   inflating: test/10858.jpg
#   inflating: test/10859.jpg
#   inflating: test/1086.jpg
#   inflating: test/10860.jpg
#   inflating: test/10861.jpg
#   inflating: test/10862.jpg
#   inflating: test/10863.jpg
#   inflating: test/10864.jpg
#   inflating: test/10865.jpg
#   inflating: test/10866.jpg
#   inflating: test/10867.jpg
#   inflating: test/10868.jpg
#   inflating: test/10869.jpg
#   inflating: test/1087.jpg
#   inflating: test/10870.jpg
#   inflating: test/10871.jpg
#   inflating: test/10872.jpg
#   inflating: test/10873.jpg
#   inflating: test/10874.jpg
#   inflating: test/10875.jpg
#   inflating: test/10876.jpg
#   inflating: test/10877.jpg
#   inflating: test/10878.jpg
#   inflating: test/10879.jpg
#   inflating: test/1088.jpg
#   inflating: test/10880.jpg
#   inflating: test/10881.jpg
#   inflating: test/10882.jpg
#   inflating: test/10883.jpg
#   inflating: test/10884.jpg
#   inflating: test/10885.jpg
#   inflating: test/10886.jpg
#   inflating: test/10887.jpg
#   inflating: test/10888.jpg
#   inflating: test/10889.jpg
#   inflating: test/1089.jpg
#   inflating: test/10890.jpg
#   inflating: test/10891.jpg
#   inflating: test/10892.jpg
#   inflating: test/10893.jpg
#   inflating: test/10894.jpg
#   inflating: test/10895.jpg
#   inflating: test/10896.jpg
#   inflating: test/10897.jpg
#   inflating: test/10898.jpg
#   inflating: test/10899.jpg
#   inflating: test/109.jpg
#   inflating: test/1090.jpg
#   inflating: test/10900.jpg
#   inflating: test/10901.jpg
#   inflating: test/10902.jpg
#   inflating: test/10903.jpg
#   inflating: test/10904.jpg
#   inflating: test/10905.jpg
#   inflating: test/10906.jpg
#   inflating: test/10907.jpg
#   inflating: test/10908.jpg
#   inflating: test/10909.jpg
#   inflating: test/1091.jpg
#   inflating: test/10910.jpg
#   inflating: test/10911.jpg
#   inflating: test/10912.jpg
#   inflating: test/10913.jpg
#   inflating: test/10914.jpg
#   inflating: test/10915.jpg
#   inflating: test/10916.jpg
#   inflating: test/10917.jpg
#   inflating: test/10918.jpg
#   inflating: test/10919.jpg
#   inflating: test/1092.jpg
#   inflating: test/10920.jpg
#   inflating: test/10921.jpg
#   inflating: test/10922.jpg
#   inflating: test/10923.jpg
#   inflating: test/10924.jpg
#   inflating: test/10925.jpg
#   inflating: test/10926.jpg
#   inflating: test/10927.jpg
#   inflating: test/10928.jpg
#   inflating: test/10929.jpg
#   inflating: test/1093.jpg
#   inflating: test/10930.jpg
#   inflating: test/10931.jpg
#   inflating: test/10932.jpg
#   inflating: test/10933.jpg
#   inflating: test/10934.jpg
#   inflating: test/10935.jpg
#   inflating: test/10936.jpg
#   inflating: test/10937.jpg
#   inflating: test/10938.jpg
#   inflating: test/10939.jpg
#   inflating: test/1094.jpg
#   inflating: test/10940.jpg
#   inflating: test/10941.jpg
#   inflating: test/10942.jpg
#   inflating: test/10943.jpg
#   inflating: test/10944.jpg
#   inflating: test/10945.jpg
#   inflating: test/10946.jpg
#   inflating: test/10947.jpg
#   inflating: test/10948.jpg
#   inflating: test/10949.jpg
#   inflating: test/1095.jpg
#   inflating: test/10950.jpg
#   inflating: test/10951.jpg
#   inflating: test/10952.jpg
#   inflating: test/10953.jpg
#   inflating: test/10954.jpg
#   inflating: test/10955.jpg
#   inflating: test/10956.jpg
#   inflating: test/10957.jpg
#   inflating: test/10958.jpg
#   inflating: test/10959.jpg
#   inflating: test/1096.jpg
#   inflating: test/10960.jpg
#   inflating: test/10961.jpg
#   inflating: test/10962.jpg
#   inflating: test/10963.jpg
#   inflating: test/10964.jpg
#   inflating: test/10965.jpg
#   inflating: test/10966.jpg
#   inflating: test/10967.jpg
#   inflating: test/10968.jpg
#   inflating: test/10969.jpg
#   inflating: test/1097.jpg
#   inflating: test/10970.jpg
#   inflating: test/10971.jpg
#   inflating: test/10972.jpg
#   inflating: test/10973.jpg
#   inflating: test/10974.jpg
#   inflating: test/10975.jpg
#   inflating: test/10976.jpg
#   inflating: test/10977.jpg
#   inflating: test/10978.jpg
#   inflating: test/10979.jpg
#   inflating: test/1098.jpg
#   inflating: test/10980.jpg
#   inflating: test/10981.jpg
#   inflating: test/10982.jpg
#   inflating: test/10983.jpg
#   inflating: test/10984.jpg
#   inflating: test/10985.jpg
#   inflating: test/10986.jpg
#   inflating: test/10987.jpg
#   inflating: test/10988.jpg
#   inflating: test/10989.jpg
#   inflating: test/1099.jpg
#   inflating: test/10990.jpg
#   inflating: test/10991.jpg
#   inflating: test/10992.jpg
#   inflating: test/10993.jpg
#   inflating: test/10994.jpg
#   inflating: test/10995.jpg
#   inflating: test/10996.jpg
#   inflating: test/10997.jpg
#   inflating: test/10998.jpg
#   inflating: test/10999.jpg
#   inflating: test/11.jpg
#   inflating: test/110.jpg
#   inflating: test/1100.jpg
#   inflating: test/11000.jpg
#   inflating: test/11001.jpg
#   inflating: test/11002.jpg
#   inflating: test/11003.jpg
#   inflating: test/11004.jpg
#   inflating: test/11005.jpg
#   inflating: test/11006.jpg
#   inflating: test/11007.jpg
#   inflating: test/11008.jpg
#   inflating: test/11009.jpg
#   inflating: test/1101.jpg
#   inflating: test/11010.jpg
#   inflating: test/11011.jpg
#   inflating: test/11012.jpg
#   inflating: test/11013.jpg
#   inflating: test/11014.jpg
#   inflating: test/11015.jpg
#   inflating: test/11016.jpg
#   inflating: test/11017.jpg
#   inflating: test/11018.jpg
#   inflating: test/11019.jpg
#   inflating: test/1102.jpg
#   inflating: test/11020.jpg
#   inflating: test/11021.jpg
#   inflating: test/11022.jpg
#   inflating: test/11023.jpg
#   inflating: test/11024.jpg
#   inflating: test/11025.jpg
#   inflating: test/11026.jpg
#   inflating: test/11027.jpg
#   inflating: test/11028.jpg
#   inflating: test/11029.jpg
#   inflating: test/1103.jpg
#   inflating: test/11030.jpg
#   inflating: test/11031.jpg
#   inflating: test/11032.jpg
#   inflating: test/11033.jpg
#   inflating: test/11034.jpg
#   inflating: test/11035.jpg
#   inflating: test/11036.jpg
#   inflating: test/11037.jpg
#   inflating: test/11038.jpg
#   inflating: test/11039.jpg
#   inflating: test/1104.jpg
#   inflating: test/11040.jpg
#   inflating: test/11041.jpg
#   inflating: test/11042.jpg
#   inflating: test/11043.jpg
#   inflating: test/11044.jpg
#   inflating: test/11045.jpg
#   inflating: test/11046.jpg
#   inflating: test/11047.jpg
#   inflating: test/11048.jpg
#   inflating: test/11049.jpg
#   inflating: test/1105.jpg
#   inflating: test/11050.jpg
#   inflating: test/11051.jpg
#   inflating: test/11052.jpg
#   inflating: test/11053.jpg
#   inflating: test/11054.jpg
#   inflating: test/11055.jpg
#   inflating: test/11056.jpg
#   inflating: test/11057.jpg
#   inflating: test/11058.jpg
#   inflating: test/11059.jpg
#   inflating: test/1106.jpg
#   inflating: test/11060.jpg
#   inflating: test/11061.jpg
#   inflating: test/11062.jpg
#   inflating: test/11063.jpg
#   inflating: test/11064.jpg
#   inflating: test/11065.jpg
#   inflating: test/11066.jpg
#   inflating: test/11067.jpg
#   inflating: test/11068.jpg
#   inflating: test/11069.jpg
#   inflating: test/1107.jpg
#   inflating: test/11070.jpg
#   inflating: test/11071.jpg
#   inflating: test/11072.jpg
#   inflating: test/11073.jpg
#   inflating: test/11074.jpg
#   inflating: test/11075.jpg
#   inflating: test/11076.jpg
#   inflating: test/11077.jpg
#   inflating: test/11078.jpg
#   inflating: test/11079.jpg
#   inflating: test/1108.jpg
#   inflating: test/11080.jpg
#   inflating: test/11081.jpg
#   inflating: test/11082.jpg
#   inflating: test/11083.jpg
#   inflating: test/11084.jpg
#   inflating: test/11085.jpg
#   inflating: test/11086.jpg
#   inflating: test/11087.jpg
#   inflating: test/11088.jpg
#   inflating: test/11089.jpg
#   inflating: test/1109.jpg
#   inflating: test/11090.jpg
#   inflating: test/11091.jpg
#   inflating: test/11092.jpg
#   inflating: test/11093.jpg
#   inflating: test/11094.jpg
#   inflating: test/11095.jpg
#   inflating: test/11096.jpg
#   inflating: test/11097.jpg
#   inflating: test/11098.jpg
#   inflating: test/11099.jpg
#   inflating: test/111.jpg
#   inflating: test/1110.jpg
#   inflating: test/11100.jpg
#   inflating: test/11101.jpg
#   inflating: test/11102.jpg
#   inflating: test/11103.jpg
#   inflating: test/11104.jpg
#   inflating: test/11105.jpg
#   inflating: test/11106.jpg
#   inflating: test/11107.jpg
#   inflating: test/11108.jpg
#   inflating: test/11109.jpg
#   inflating: test/1111.jpg
#   inflating: test/11110.jpg
#   inflating: test/11111.jpg
#   inflating: test/11112.jpg
#   inflating: test/11113.jpg
#   inflating: test/11114.jpg
#   inflating: test/11115.jpg
#   inflating: test/11116.jpg
#   inflating: test/11117.jpg
#   inflating: test/11118.jpg
#   inflating: test/11119.jpg
#   inflating: test/1112.jpg
#   inflating: test/11120.jpg
#   inflating: test/11121.jpg
#   inflating: test/11122.jpg
#   inflating: test/11123.jpg
#   inflating: test/11124.jpg
#   inflating: test/11125.jpg
#   inflating: test/11126.jpg
#   inflating: test/11127.jpg
#   inflating: test/11128.jpg
#   inflating: test/11129.jpg
# ...
#   inflating: train/dog.9622.jpg
#   inflating: train/dog.9623.jpg
#   inflating: train/dog.9624.jpg
#   inflating: train/dog.9625.jpg
#   inflating: train/dog.9626.jpg
#   inflating: train/dog.9627.jpg
#   inflating: train/dog.9628.jpg
#   inflating: train/dog.9629.jpg
#   inflating: train/dog.963.jpg
#   inflating: train/dog.9630.jpg
#   inflating: train/dog.9631.jpg
#   inflating: train/dog.9632.jpg
#   inflating: train/dog.9633.jpg
#   inflating: train/dog.9634.jpg
#   inflating: train/dog.9635.jpg
#   inflating: train/dog.9636.jpg
#   inflating: train/dog.9637.jpg
#   inflating: train/dog.9638.jpg
#   inflating: train/dog.9639.jpg
#   inflating: train/dog.964.jpg
#   inflating: train/dog.9640.jpg
#   inflating: train/dog.9641.jpg
#   inflating: train/dog.9642.jpg
#   inflating: train/dog.9643.jpg
#   inflating: train/dog.9644.jpg
#   inflating: train/dog.9645.jpg
#   inflating: train/dog.9646.jpg
#   inflating: train/dog.9647.jpg
#   inflating: train/dog.9648.jpg
#   inflating: train/dog.9649.jpg
#   inflating: train/dog.965.jpg
#   inflating: train/dog.9650.jpg
#   inflating: train/dog.9651.jpg
#   inflating: train/dog.9652.jpg
#   inflating: train/dog.9653.jpg
#   inflating: train/dog.9654.jpg
#   inflating: train/dog.9655.jpg
#   inflating: train/dog.9656.jpg
#   inflating: train/dog.9657.jpg
#   inflating: train/dog.9658.jpg
#   inflating: train/dog.9659.jpg
#   inflating: train/dog.966.jpg
#   inflating: train/dog.9660.jpg
#   inflating: train/dog.9661.jpg
#   inflating: train/dog.9662.jpg
#   inflating: train/dog.9663.jpg
#   inflating: train/dog.9664.jpg
#   inflating: train/dog.9665.jpg
#   inflating: train/dog.9666.jpg
#   inflating: train/dog.9667.jpg
#   inflating: train/dog.9668.jpg
#   inflating: train/dog.9669.jpg
#   inflating: train/dog.967.jpg
#   inflating: train/dog.9670.jpg
#   inflating: train/dog.9671.jpg
#   inflating: train/dog.9672.jpg
#   inflating: train/dog.9673.jpg
#   inflating: train/dog.9674.jpg
#   inflating: train/dog.9675.jpg
#   inflating: train/dog.9676.jpg
#   inflating: train/dog.9677.jpg
#   inflating: train/dog.9678.jpg
#   inflating: train/dog.9679.jpg
#   inflating: train/dog.968.jpg
#   inflating: train/dog.9680.jpg
#   inflating: train/dog.9681.jpg
#   inflating: train/dog.9682.jpg
#   inflating: train/dog.9683.jpg
#   inflating: train/dog.9684.jpg
#   inflating: train/dog.9685.jpg
#   inflating: train/dog.9686.jpg
#   inflating: train/dog.9687.jpg
#   inflating: train/dog.9688.jpg
#   inflating: train/dog.9689.jpg
#   inflating: train/dog.969.jpg
#   inflating: train/dog.9690.jpg
#   inflating: train/dog.9691.jpg
#   inflating: train/dog.9692.jpg
#   inflating: train/dog.9693.jpg
#   inflating: train/dog.9694.jpg
#   inflating: train/dog.9695.jpg
#   inflating: train/dog.9696.jpg
#   inflating: train/dog.9697.jpg
#   inflating: train/dog.9698.jpg
#   inflating: train/dog.9699.jpg
#   inflating: train/dog.97.jpg
#   inflating: train/dog.970.jpg
#   inflating: train/dog.9700.jpg
#   inflating: train/dog.9701.jpg
#   inflating: train/dog.9702.jpg
#   inflating: train/dog.9703.jpg
#   inflating: train/dog.9704.jpg
#   inflating: train/dog.9705.jpg
#   inflating: train/dog.9706.jpg
#   inflating: train/dog.9707.jpg
#   inflating: train/dog.9708.jpg
#   inflating: train/dog.9709.jpg
#   inflating: train/dog.971.jpg
#   inflating: train/dog.9710.jpg
#   inflating: train/dog.9711.jpg
#   inflating: train/dog.9712.jpg
#   inflating: train/dog.9713.jpg
#   inflating: train/dog.9714.jpg
#   inflating: train/dog.9715.jpg
#   inflating: train/dog.9716.jpg
#   inflating: train/dog.9717.jpg
#   inflating: train/dog.9718.jpg
#   inflating: train/dog.9719.jpg
#   inflating: train/dog.972.jpg
#   inflating: train/dog.9720.jpg
#   inflating: train/dog.9721.jpg
#   inflating: train/dog.9722.jpg
#   inflating: train/dog.9723.jpg
#   inflating: train/dog.9724.jpg
#   inflating: train/dog.9725.jpg
#   inflating: train/dog.9726.jpg
#   inflating: train/dog.9727.jpg
#   inflating: train/dog.9728.jpg
#   inflating: train/dog.9729.jpg
#   inflating: train/dog.973.jpg
#   inflating: train/dog.9730.jpg
#   inflating: train/dog.9731.jpg
#   inflating: train/dog.9732.jpg
#   inflating: train/dog.9733.jpg
#   inflating: train/dog.9734.jpg
#   inflating: train/dog.9735.jpg
#   inflating: train/dog.9736.jpg
#   inflating: train/dog.9737.jpg
#   inflating: train/dog.9738.jpg
#   inflating: train/dog.9739.jpg
#   inflating: train/dog.974.jpg
#   inflating: train/dog.9740.jpg
#   inflating: train/dog.9741.jpg
#   inflating: train/dog.9742.jpg
#   inflating: train/dog.9743.jpg
#   inflating: train/dog.9744.jpg
#   inflating: train/dog.9745.jpg
#   inflating: train/dog.9746.jpg
#   inflating: train/dog.9747.jpg
#   inflating: train/dog.9748.jpg
#   inflating: train/dog.9749.jpg
#   inflating: train/dog.975.jpg
#   inflating: train/dog.9750.jpg
#   inflating: train/dog.9751.jpg
#   inflating: train/dog.9752.jpg
#   inflating: train/dog.9753.jpg
#   inflating: train/dog.9754.jpg
#   inflating: train/dog.9755.jpg
#   inflating: train/dog.9756.jpg
#   inflating: train/dog.9757.jpg
#   inflating: train/dog.9758.jpg
#   inflating: train/dog.9759.jpg
#   inflating: train/dog.976.jpg
#   inflating: train/dog.9760.jpg
#   inflating: train/dog.9761.jpg
#   inflating: train/dog.9762.jpg
#   inflating: train/dog.9763.jpg
#   inflating: train/dog.9764.jpg
#   inflating: train/dog.9765.jpg
#   inflating: train/dog.9766.jpg
#   inflating: train/dog.9767.jpg
#   inflating: train/dog.9768.jpg
#   inflating: train/dog.9769.jpg
#   inflating: train/dog.977.jpg
#   inflating: train/dog.9770.jpg
#   inflating: train/dog.9771.jpg
#   inflating: train/dog.9772.jpg
#   inflating: train/dog.9773.jpg
#   inflating: train/dog.9774.jpg
#   inflating: train/dog.9775.jpg
#   inflating: train/dog.9776.jpg
#   inflating: train/dog.9777.jpg
#   inflating: train/dog.9778.jpg
#   inflating: train/dog.9779.jpg
#   inflating: train/dog.978.jpg
#   inflating: train/dog.9780.jpg
#   inflating: train/dog.9781.jpg
#   inflating: train/dog.9782.jpg
#   inflating: train/dog.9783.jpg
#   inflating: train/dog.9784.jpg
#   inflating: train/dog.9785.jpg
#   inflating: train/dog.9786.jpg
#   inflating: train/dog.9787.jpg
#   inflating: train/dog.9788.jpg
#   inflating: train/dog.9789.jpg
#   inflating: train/dog.979.jpg
#   inflating: train/dog.9790.jpg
#   inflating: train/dog.9791.jpg
#   inflating: train/dog.9792.jpg
#   inflating: train/dog.9793.jpg
#   inflating: train/dog.9794.jpg
#   inflating: train/dog.9795.jpg
#   inflating: train/dog.9796.jpg
#   inflating: train/dog.9797.jpg
#   inflating: train/dog.9798.jpg
#   inflating: train/dog.9799.jpg
#   inflating: train/dog.98.jpg
#   inflating: train/dog.980.jpg
#   inflating: train/dog.9800.jpg
#   inflating: train/dog.9801.jpg
#   inflating: train/dog.9802.jpg
#   inflating: train/dog.9803.jpg
#   inflating: train/dog.9804.jpg
#   inflating: train/dog.9805.jpg
#   inflating: train/dog.9806.jpg
#   inflating: train/dog.9807.jpg
#   inflating: train/dog.9808.jpg
#   inflating: train/dog.9809.jpg
#   inflating: train/dog.981.jpg
#   inflating: train/dog.9810.jpg
#   inflating: train/dog.9811.jpg
#   inflating: train/dog.9812.jpg
#   inflating: train/dog.9813.jpg
#   inflating: train/dog.9814.jpg
#   inflating: train/dog.9815.jpg
#   inflating: train/dog.9816.jpg
#   inflating: train/dog.9817.jpg
#   inflating: train/dog.9818.jpg
#   inflating: train/dog.9819.jpg
#   inflating: train/dog.982.jpg
#   inflating: train/dog.9820.jpg
#   inflating: train/dog.9821.jpg
#   inflating: train/dog.9822.jpg
#   inflating: train/dog.9823.jpg
#   inflating: train/dog.9824.jpg
#   inflating: train/dog.9825.jpg
#   inflating: train/dog.9826.jpg
#   inflating: train/dog.9827.jpg
#   inflating: train/dog.9828.jpg
#   inflating: train/dog.9829.jpg
#   inflating: train/dog.983.jpg
#   inflating: train/dog.9830.jpg
#   inflating: train/dog.9831.jpg
#   inflating: train/dog.9832.jpg
#   inflating: train/dog.9833.jpg
#   inflating: train/dog.9834.jpg
#   inflating: train/dog.9835.jpg
#   inflating: train/dog.9836.jpg
#   inflating: train/dog.9837.jpg
#   inflating: train/dog.9838.jpg
#   inflating: train/dog.9839.jpg
#   inflating: train/dog.984.jpg
#   inflating: train/dog.9840.jpg
#   inflating: train/dog.9841.jpg
#   inflating: train/dog.9842.jpg
#   inflating: train/dog.9843.jpg
#   inflating: train/dog.9844.jpg
#   inflating: train/dog.9845.jpg
#   inflating: train/dog.9846.jpg
#   inflating: train/dog.9847.jpg
#   inflating: train/dog.9848.jpg
#   inflating: train/dog.9849.jpg
#   inflating: train/dog.985.jpg
#   inflating: train/dog.9850.jpg
#   inflating: train/dog.9851.jpg
#   inflating: train/dog.9852.jpg
#   inflating: train/dog.9853.jpg
#   inflating: train/dog.9854.jpg
#   inflating: train/dog.9855.jpg
#   inflating: train/dog.9856.jpg
#   inflating: train/dog.9857.jpg
#   inflating: train/dog.9858.jpg
#   inflating: train/dog.9859.jpg
#   inflating: train/dog.986.jpg
#   inflating: train/dog.9860.jpg
#   inflating: train/dog.9861.jpg
#   inflating: train/dog.9862.jpg
#   inflating: train/dog.9863.jpg
#   inflating: train/dog.9864.jpg
#   inflating: train/dog.9865.jpg
#   inflating: train/dog.9866.jpg
#   inflating: train/dog.9867.jpg
#   inflating: train/dog.9868.jpg
#   inflating: train/dog.9869.jpg
#   inflating: train/dog.987.jpg
#   inflating: train/dog.9870.jpg
#   inflating: train/dog.9871.jpg
#   inflating: train/dog.9872.jpg
#   inflating: train/dog.9873.jpg
#   inflating: train/dog.9874.jpg
#   inflating: train/dog.9875.jpg
#   inflating: train/dog.9876.jpg
#   inflating: train/dog.9877.jpg
#   inflating: train/dog.9878.jpg
#   inflating: train/dog.9879.jpg
#   inflating: train/dog.988.jpg
#   inflating: train/dog.9880.jpg
#   inflating: train/dog.9881.jpg
#   inflating: train/dog.9882.jpg
#   inflating: train/dog.9883.jpg
#   inflating: train/dog.9884.jpg
#   inflating: train/dog.9885.jpg
#   inflating: train/dog.9886.jpg
#   inflating: train/dog.9887.jpg
#   inflating: train/dog.9888.jpg
#   inflating: train/dog.9889.jpg
#   inflating: train/dog.989.jpg
#   inflating: train/dog.9890.jpg
#   inflating: train/dog.9891.jpg
#   inflating: train/dog.9892.jpg
#   inflating: train/dog.9893.jpg
#   inflating: train/dog.9894.jpg
#   inflating: train/dog.9895.jpg
#   inflating: train/dog.9896.jpg
#   inflating: train/dog.9897.jpg
#   inflating: train/dog.9898.jpg
#   inflating: train/dog.9899.jpg
#   inflating: train/dog.99.jpg
#   inflating: train/dog.990.jpg
#   inflating: train/dog.9900.jpg
#   inflating: train/dog.9901.jpg
#   inflating: train/dog.9902.jpg
#   inflating: train/dog.9903.jpg
#   inflating: train/dog.9904.jpg
#   inflating: train/dog.9905.jpg
#   inflating: train/dog.9906.jpg
#   inflating: train/dog.9907.jpg
#   inflating: train/dog.9908.jpg
#   inflating: train/dog.9909.jpg
#   inflating: train/dog.991.jpg
#   inflating: train/dog.9910.jpg
#   inflating: train/dog.9911.jpg
#   inflating: train/dog.9912.jpg
#   inflating: train/dog.9913.jpg
#   inflating: train/dog.9914.jpg
#   inflating: train/dog.9915.jpg
#   inflating: train/dog.9916.jpg
#   inflating: train/dog.9917.jpg
#   inflating: train/dog.9918.jpg
#   inflating: train/dog.9919.jpg
#   inflating: train/dog.992.jpg
#   inflating: train/dog.9920.jpg
#   inflating: train/dog.9921.jpg
#   inflating: train/dog.9922.jpg
#   inflating: train/dog.9923.jpg
#   inflating: train/dog.9924.jpg
#   inflating: train/dog.9925.jpg
#   inflating: train/dog.9926.jpg
#   inflating: train/dog.9927.jpg
#   inflating: train/dog.9928.jpg
#   inflating: train/dog.9929.jpg
#   inflating: train/dog.993.jpg
#   inflating: train/dog.9930.jpg
#   inflating: train/dog.9931.jpg
#   inflating: train/dog.9932.jpg
#   inflating: train/dog.9933.jpg
#   inflating: train/dog.9934.jpg
#   inflating: train/dog.9935.jpg
#   inflating: train/dog.9936.jpg
#   inflating: train/dog.9937.jpg
#   inflating: train/dog.9938.jpg
#   inflating: train/dog.9939.jpg
#   inflating: train/dog.994.jpg
#   inflating: train/dog.9940.jpg
#   inflating: train/dog.9941.jpg
#   inflating: train/dog.9942.jpg
#   inflating: train/dog.9943.jpg
#   inflating: train/dog.9944.jpg
#   inflating: train/dog.9945.jpg
#   inflating: train/dog.9946.jpg
#   inflating: train/dog.9947.jpg
#   inflating: train/dog.9948.jpg
#   inflating: train/dog.9949.jpg
#   inflating: train/dog.995.jpg
#   inflating: train/dog.9950.jpg
#   inflating: train/dog.9951.jpg
#   inflating: train/dog.9952.jpg
#   inflating: train/dog.9953.jpg
#   inflating: train/dog.9954.jpg
#   inflating: train/dog.9955.jpg
#   inflating: train/dog.9956.jpg
#   inflating: train/dog.9957.jpg
#   inflating: train/dog.9958.jpg
#   inflating: train/dog.9959.jpg
#   inflating: train/dog.996.jpg
#   inflating: train/dog.9960.jpg
#   inflating: train/dog.9961.jpg
#   inflating: train/dog.9962.jpg
#   inflating: train/dog.9963.jpg
#   inflating: train/dog.9964.jpg
#   inflating: train/dog.9965.jpg
#   inflating: train/dog.9966.jpg
#   inflating: train/dog.9967.jpg
#   inflating: train/dog.9968.jpg
#   inflating: train/dog.9969.jpg
#   inflating: train/dog.997.jpg
#   inflating: train/dog.9970.jpg
#   inflating: train/dog.9971.jpg
#   inflating: train/dog.9972.jpg
#   inflating: train/dog.9973.jpg
#   inflating: train/dog.9974.jpg
#   inflating: train/dog.9975.jpg
#   inflating: train/dog.9976.jpg
#   inflating: train/dog.9977.jpg
#   inflating: train/dog.9978.jpg
#   inflating: train/dog.9979.jpg
#   inflating: train/dog.998.jpg
#   inflating: train/dog.9980.jpg
#   inflating: train/dog.9981.jpg
#   inflating: train/dog.9982.jpg
#   inflating: train/dog.9983.jpg
#   inflating: train/dog.9984.jpg
#   inflating: train/dog.9985.jpg
#   inflating: train/dog.9986.jpg
#   inflating: train/dog.9987.jpg
#   inflating: train/dog.9988.jpg
#   inflating: train/dog.9989.jpg
#   inflating: train/dog.999.jpg
#   inflating: train/dog.9990.jpg
#   inflating: train/dog.9991.jpg
#   inflating: train/dog.9992.jpg
#   inflating: train/dog.9993.jpg
#   inflating: train/dog.9994.jpg
#   inflating: train/dog.9995.jpg
#   inflating: train/dog.9996.jpg
#   inflating: train/dog.9997.jpg
#   inflating: train/dog.9998.jpg
#   inflating: train/dog.9999.jpg
# mkdir: cannot create directory ‘valid’: File exists
# mkdir: cannot create directory ‘results’: File exists

# %%
# %cd $DATA_HOME_DIR/train
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux/train

# %%
g = glob('*.jpg')
shuf = np.random.permutation(g)
for i in range(1000): os.rename(shuf[i], DATA_HOME_DIR+'/valid/' + shuf[i])

# %%
from shutil import copyfile

# %%
g = glob('*.jpg')
shuf = np.random.permutation(g)
for i in range(100): copyfile(shuf[i], DATA_HOME_DIR+'/sample/train/' + shuf[i])

# %%
# %cd $DATA_HOME_DIR/valid
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux/valid

# %%
g = glob('*.jpg')
shuf = np.random.permutation(g)
for i in range(25): copyfile(shuf[i], DATA_HOME_DIR+'/sample/valid/' + shuf[i])

# %% [markdown]
# ## Rearrange image files into their respective directories

# %%
#Divide cat/dog images into separate directories

# %cd $DATA_HOME_DIR/sample/train
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/

# %cd $DATA_HOME_DIR/sample/valid
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/

# %cd $DATA_HOME_DIR/valid
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/

# %cd $DATA_HOME_DIR/train
# %mkdir cats
# %mkdir dogs
# %mv cat.*.jpg cats/
# %mv dog.*.jpg dogs/
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux/sample/train
# /home/james/co/courses/deeplearning1/nbs/data/redux/sample/valid
# /home/james/co/courses/deeplearning1/nbs/data/redux/valid
# /home/james/co/courses/deeplearning1/nbs/data/redux/train

# %%
# Create single 'unknown' class for test set
# %cd $DATA_HOME_DIR/test
# %mv *.jpg unknown/
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux/test

# %% [markdown]
# ## Finetuning and Training

# %%
# %cd $DATA_HOME_DIR

#Set path to sample/ path if desired
path = DATA_HOME_DIR + '/sample/'
test_path = DATA_HOME_DIR + '/test/' #We use all the test data
results_path=DATA_HOME_DIR + '/results/'
train_path=path + '/train/'
valid_path=path + '/valid/'
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux

# %%
#import Vgg16 helper class
vgg = Vgg16()

# %%
#Set constants. You can experiment with no_of_epochs to improve the model
batch_size=64
no_of_epochs=3

# %%
#Finetune the model
batches = vgg.get_batches(train_path, batch_size=batch_size)
val_batches = vgg.get_batches(valid_path, batch_size=batch_size*2)
vgg.finetune(batches)

#Not sure if we set this for all fits
vgg.model.optimizer.lr = 0.01
# Out:
# Found 100 images belonging to 2 classes.
# Found 25 images belonging to 2 classes.

# %%
#Notice we are passing in the validation dataset to the fit() method
#For each epoch we test our model against the validation set
latest_weights_filename = None
for epoch in range(no_of_epochs):
    print("Running epoch: %d" % epoch)
    vgg.fit(batches, val_batches, nb_epoch=1)
    latest_weights_filename = 'ft%d.h5' % epoch
    vgg.model.save_weights(results_path+latest_weights_filename)
print("Completed %s fit operations" % no_of_epochs)
# Out:
# Running epoch: 0
# Epoch 1/1
# 100/100 [==============================] - 2s - loss: 2.1323 - acc: 0.4900 - val_loss: 0.0924 - val_acc: 0.9600
# Running epoch: 1
# Epoch 1/1
# 100/100 [==============================] - 1s - loss: 0.0710 - acc: 0.9800 - val_loss: 0.6448 - val_acc: 0.9600
# Running epoch: 2
# Epoch 1/1
# 100/100 [==============================] - 1s - loss: 0.1669 - acc: 0.9900 - val_loss: 0.6458 - val_acc: 0.9600
# Completed 3 fit operations

# %% [markdown]
# ## Generate Predictions

# %% [markdown]
# Let's use our new model to make predictions on the test dataset

# %%
vgg.model.load_weights(results_path+'ft2.h5')

# %%
batches, preds = vgg.test(test_path, batch_size = batch_size*2)
# Out:
# Found 12500 images belonging to 1 classes.

# %%
#For every image, vgg.test() generates two probabilities 
#based on how we've ordered the cats/dogs directories.
#It looks like column one is cats and column two is dogs
print(preds[:5])

filenames = batches.filenames
print(filenames[:5])
# Out:
# [[  7.1466e-44   1.0000e+00]
#  [  7.0919e-30   1.0000e+00]
#  [  1.0000e+00   1.3541e-21]
#  [  1.0000e+00   1.3896e-23]
#  [  8.3765e-21   1.0000e+00]]
# ['unknown/2222.jpg', 'unknown/3424.jpg', 'unknown/10013.jpg', 'unknown/8591.jpg', 'unknown/4456.jpg']

# %%
#You can verify the column ordering by viewing some images
from PIL import Image
Image.open(test_path + filenames[2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=470x500 at 0x7F334AF4A400>

# %%
#Save our test results arrays so we can use them again later
save_array(results_path + 'test_preds.dat', preds)
save_array(results_path + 'filenames.dat', filenames)

# %% [markdown]
# ## Validate Predictions

# %% [markdown]
# Keras' *fit()* function conveniently shows us the value of the loss function, and the accuracy, after every epoch ("*epoch*" refers to one full run through all training examples). The most important metrics for us to look at are for the validation set, since we want to check for over-fitting.
#
# - **Tip**: with our first model we should try to overfit before we start worrying about how to reduce over-fitting - there's no point even thinking about regularization, data augmentation, etc if you're still under-fitting! (We'll be looking at these techniques shortly).
#
# As well as looking at the overall metrics, it's also a good idea to look at examples of each of:
# 1. A few correct labels at random
# 2. A few incorrect labels at random
# 3. The most correct labels of each class (ie those with highest probability that are correct)
# 4. The most incorrect labels of each class (ie those with highest probability that are incorrect)
# 5. The most uncertain labels (ie those with probability closest to 0.5).

# %% [markdown]
# Let's see what we can learn from these examples. (In general, this is a particularly useful technique for debugging problems in the model. However, since this model is so simple, there may not be too much to learn at this stage.)
#
# Calculate predictions on validation set, so we can find correct and incorrect examples:

# %%
vgg.model.load_weights(results_path+latest_weights_filename)

# %%
val_batches, probs = vgg.test(valid_path, batch_size = batch_size)
# Out:
# Found 25 images belonging to 2 classes.

# %%
filenames = val_batches.filenames
expected_labels = val_batches.classes #0 or 1

#Round our predictions to 0/1 to generate labels
our_predictions = probs[:,0]
our_labels = np.round(1-our_predictions)

# %%
from keras.preprocessing import image

#Helper function to plot images by index in the validation set 
#Plots is a helper function in utils.py
def plots_idx(idx, titles=None):
    plots([image.load_img(valid_path + filenames[i]) for i in idx], titles=titles)
    
#Number of images to view for each visualization task
n_view = 4

# %%
#1. A few correct labels at random
correct = np.where(our_labels==expected_labels)[0]
print("Found %d correct labels" % len(correct))
idx = permutation(correct)[:n_view]
plots_idx(idx, our_predictions[idx])
# Out:
# Found 24 correct labels

# %%
#2. A few incorrect labels at random
incorrect = np.where(our_labels!=expected_labels)[0]
print("Found %d incorrect labels" % len(incorrect))
idx = permutation(incorrect)[:n_view]
plots_idx(idx, our_predictions[idx])
# Out:
# Found 1 incorrect labels

# %%
#3a. The images we most confident were cats, and are actually cats
correct_cats = np.where((our_labels==0) & (our_labels==expected_labels))[0]
print("Found %d confident correct cats labels" % len(correct_cats))
most_correct_cats = np.argsort(our_predictions[correct_cats])[::-1][:n_view]
plots_idx(correct_cats[most_correct_cats], our_predictions[correct_cats][most_correct_cats])
# Out:
# Found 13 confident correct cats labels

# %%
#3b. The images we most confident were dogs, and are actually dogs
correct_dogs = np.where((our_labels==1) & (our_labels==expected_labels))[0]
print("Found %d confident correct dogs labels" % len(correct_dogs))
most_correct_dogs = np.argsort(our_predictions[correct_dogs])[:n_view]
plots_idx(correct_dogs[most_correct_dogs], our_predictions[correct_dogs][most_correct_dogs])
# Out:
# Found 11 confident correct dogs labels

# %%
#4a. The images we were most confident were cats, but are actually dogs
incorrect_cats = np.where((our_labels==0) & (our_labels!=expected_labels))[0]
print("Found %d incorrect cats" % len(incorrect_cats))
if len(incorrect_cats):
    most_incorrect_cats = np.argsort(our_predictions[incorrect_cats])[::-1][:n_view]
    plots_idx(incorrect_cats[most_incorrect_cats], our_predictions[incorrect_cats][most_incorrect_cats])
# Out:
# Found 0 incorrect cats

# %%
#4b. The images we were most confident were dogs, but are actually cats
incorrect_dogs = np.where((our_labels==1) & (our_labels!=expected_labels))[0]
print("Found %d incorrect dogs" % len(incorrect_dogs))
if len(incorrect_dogs):
    most_incorrect_dogs = np.argsort(our_predictions[incorrect_dogs])[:n_view]
    plots_idx(incorrect_dogs[most_incorrect_dogs], our_predictions[incorrect_dogs][most_incorrect_dogs])
# Out:
# Found 1 incorrect dogs

# %%
#5. The most uncertain labels (ie those with probability closest to 0.5).
most_uncertain = np.argsort(np.abs(our_predictions-0.5))
plots_idx(most_uncertain[:n_view], our_predictions[most_uncertain])

# %% [markdown]
# Perhaps the most common way to analyze the result of a classification model is to use a [confusion matrix](http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/). Scikit-learn has a convenient function we can use for this purpose:

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(expected_labels, our_labels)

# %% [markdown]
# We can just print out the confusion matrix, or we can show a graphical view (which is mainly useful for dependents with a larger number of categories).

# %%
plot_confusion_matrix(cm, val_batches.class_indices)
# Out:
# [[13  1]
#  [ 0 11]]

# %% [markdown]
# ## Submit Predictions to Kaggle!

# %% [markdown]
# Here's the format Kaggle requires for new submissions:
# ```
# imageId,isDog
# 1242, .3984
# 3947, .1000
# 4539, .9082
# 2345, .0000
# ```
#
# Kaggle wants the imageId followed by the probability of the image being a dog. Kaggle uses a metric called [Log Loss](http://wiki.fast.ai/index.php/Log_Loss) to evaluate your submission.

# %%
#Load our test predictions from file
preds = load_array(results_path + 'test_preds.dat')
filenames = load_array(results_path + 'filenames.dat')

# %%
#Grab the dog prediction column
isdog = preds[:,1]
print("Raw Predictions: " + str(isdog[:5]))
print("Mid Predictions: " + str(isdog[(isdog < .6) & (isdog > .4)]))
print("Edge Predictions: " + str(isdog[(isdog == 1) | (isdog == 0)]))
# Out:
# Raw Predictions: [  1.0000e+00   1.0000e+00   1.3541e-21   1.3896e-23   1.0000e+00]
# Mid Predictions: [ 0.4535  0.5401  0.5342  0.4011  0.5782  0.4879  0.5903  0.4039  0.5964  0.5365  0.5586  0.4274
#   0.5508  0.4801  0.4794  0.4642  0.4274  0.5156  0.429 ]
# Edge Predictions: [ 1.  1.  1. ...,  1.  1.  1.]

# %% [markdown]
# [Log Loss](http://wiki.fast.ai/index.php/Log_Loss) doesn't support probability values of 0 or 1--they are undefined (and we have many). Fortunately, Kaggle helps us by offsetting our 0s and 1s by a very small value. So if we upload our submission now we will have lots of .99999999 and .000000001 values. This seems good, right?
#
# Not so. There is an additional twist due to how log loss is calculated--log loss rewards predictions that are confident and correct (p=.9999,label=1), but it punishes predictions that are confident and wrong far more (p=.0001,label=1). See visualization below.

# %%
#Visualize Log Loss when True value = 1
#y-axis is log loss, x-axis is probabilty that label = 1
#As you can see Log Loss increases rapidly as we approach 0
#But increases slowly as our predicted probability gets closer to 1
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import log_loss

x = [i*.0001 for i in range(1,10000)]
y = [log_loss([1],[[i*.0001,1-(i*.0001)]],eps=1e-15,labels=['cat','dog']) for i in range(1,10000,1)]

plt.plot(x, y)
plt.axis([-.05, 1.1, -.8, 10])
plt.title("Log Loss when true label = 1")
plt.xlabel("predicted probability")
plt.ylabel("log loss")

plt.show()
# Out:
# /home/james/.anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
#So to play it safe, we use a sneaky trick to round down our edge predictions
#Swap all ones with .95 and all zeros with .05
isdog = isdog.clip(min=0.05, max=0.95)

# %%
#Extract imageIds from the filenames in our test/unknown directory 
filenames = batches.filenames
ids = np.array([int(f[8:f.find('.')]) for f in filenames])

# %% [markdown]
# Here we join the two columns into an array of [imageId, isDog]

# %%
subm = np.stack([ids,isdog], axis=1)
subm[:5]
# Out:
# array([[  2.2220e+03,   9.5000e-01],
#        [  3.4240e+03,   9.5000e-01],
#        [  1.0013e+04,   5.0000e-02],
#        [  8.5910e+03,   5.0000e-02],
#        [  4.4560e+03,   9.5000e-01]])

# %%
# %cd $DATA_HOME_DIR
submission_file_name = 'submission1.csv'
np.savetxt(submission_file_name, subm, fmt='%d,%.5f', header='id,label', comments='')
# Out:
# /home/james/co/courses/deeplearning1/nbs/data/redux

# %%
from IPython.display import FileLink
# %cd $LESSON_HOME_DIR
FileLink('data/redux/'+submission_file_name)
# Out:
# /home/james/co/courses/deeplearning1/nbs
# /home/james/co/courses/deeplearning1/nbs/data/redux/submission1.csv

# %% [markdown]
# You can download this file and submit on the Kaggle website or use the Kaggle command line tool's "submit" method.
